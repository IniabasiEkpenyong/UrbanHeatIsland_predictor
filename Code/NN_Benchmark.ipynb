# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# Visualization
import matplotlib.pyplot as plt
#import seaborn as sns

# Data Science
import numpy as np
import pandas as pd

# Multi-dimensional arrays and datasets
import xarray as xr

# Geospatial raster data handling
import rioxarray as rxr

# Geospatial data analysis
#import geopandas as gpd

# Geospatial operations
import rasterio
from rasterio import windows  
from rasterio import features  
from rasterio import warp
from rasterio.warp import transform_bounds 
from rasterio.windows import from_bounds 

# Image Processing
from PIL import Image

# Coordinate transformations
from pyproj import Proj, Transformer, CRS

# Feature Engineering
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Machine Learning
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

# Planetary Computer Tools
import pystac_client
import planetary_computer as pc
from pystac.extensions.eo import EOExtension as eo

# Others
import os
from tqdm import tqdm
# Out:
# Failed to import TF-Keras. Please note that TF-Keras is not installed by default when you install TensorFlow Probability. This is so that JAX-only users do not have to install TensorFlow or TF-Keras. To use TensorFlow Probability with TensorFlow, please install the tf-keras or tf-keras-nightly package.
# This can be be done through installing the tensorflow-probability[tf] extra.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 51
#      49 from tensorflow.keras import regularizers
#      50 from tensorflow.keras.optimizers import Adam
# ---> 51 import tensorflow_probability as tfp
#      53 # Planetary Computer Tools
#      54 import pystac_client
#
# File ~/anaconda3/envs/UHI/lib/python3.10/site-packages/tensorflow_probability/__init__.py:22
#      15 """Tools for probabilistic reasoning in TensorFlow."""
#      17 # Contributors to the `python/` dir should not alter this file; instead update
#      18 # `python/__init__.py` as necessary.
#      19
#      20 # from tensorflow_probability.google import staging  # DisableOnExport
#      21 # from tensorflow_probability.google import tfp_google  # DisableOnExport
# ---> 22 from tensorflow_probability.python import *  # pylint: disable=wildcard-import
#      23 from tensorflow_probability.python.version import __version__
#      25 # tfp_google.bind(globals())  # DisableOnExport
#      26 # del tfp_google  # DisableOnExport
#
# File ~/anaconda3/envs/UHI/lib/python3.10/site-packages/tensorflow_probability/python/__init__.py:152
#     149 if _tf_loaded():
#     150   # Non-lazy load of packages that register with tensorflow or keras.
#     151   for pkg_name in _maybe_nonlazy_load:
# --> 152     dir(globals()[pkg_name])  # Forces loading the package from its lazy loader.
#     155 all_util.remove_undocumented(__name__, _lazy_load + _maybe_nonlazy_load)
#
# File ~/anaconda3/envs/UHI/lib/python3.10/site-packages/tensorflow_probability/python/internal/lazy_loader.py:60, in LazyLoader.__dir__(self)
#      59 def __dir__(self):
# ---> 60   module = self._load()
#      61   return dir(module)
#
# File ~/anaconda3/envs/UHI/lib/python3.10/site-packages/tensorflow_probability/python/internal/lazy_loader.py:40, in LazyLoader._load(self)
#      38 """Load the module and insert it into the parent's globals."""
#      39 if callable(self._on_first_access):
# ---> 40   self._on_first_access()
#      41   self._on_first_access = None
#      42 # Import the target module and insert it into the parent's namespace
#
# File ~/anaconda3/envs/UHI/lib/python3.10/site-packages/tensorflow_probability/python/__init__.py:79, in _validate_tf_environment(package)
#      77 if required_tensorflow_version[0] == '2':
#      78   try:
# ---> 79     import tf_keras  # pylint: disable=unused-import
#      80   except (ImportError, ModuleNotFoundError):
#      81     # Print more informative error message, then reraise.
#      82     print('\n\nFailed to import TF-Keras. Please note that TF-Keras is not '
#      83           'installed by default when you install TensorFlow Probability. '
#      84           'This is so that JAX-only users do not have to install TensorFlow '
#    (...)
#      87           'This can be be done through installing the '
#      88           'tensorflow-probability[tf] extra.\n\n')
#
# ModuleNotFoundError: No module named 'tf_keras'

# %%
def combine_two_datasets(dataset1,dataset2):
    '''
    Returns a  vertically concatenated dataset.
    Attributes:
    dataset1 - Dataset 1 to be combined 
    dataset2 - Dataset 2 to be combined
    '''
    
    data = pd.concat([dataset1,dataset2], axis=1)
    return data

# %%
# Extracts satellite band values from a GeoTIFF based on coordinates from a csv file and returns them in a DataFrame.

def map_satellite_data(tiff_path, csv_path):
    
    # Load the GeoTIFF data
    data = rxr.open_rasterio(tiff_path)
    tiff_crs = data.rio.crs

    # Read the Excel file using pandas
    df = pd.read_csv(csv_path)
    latitudes = df['Latitude'].values
    longitudes = df['Longitude'].values

    # 3. Convert lat/long to the GeoTIFF's CRS
    # Create a Proj object for EPSG:4326 (WGS84 - lat/long) and the GeoTIFF's CRS
    proj_wgs84 = Proj(init='epsg:4326')  # EPSG:4326 is the common lat/long CRS
    proj_tiff = Proj(tiff_crs)
    
    # Create a transformer object
    transformer = Transformer.from_proj(proj_wgs84, proj_tiff)

    vals = [[] for _ in range(n_inputs)]


# Iterate over the latitudes and longitudes, and extract the corresponding band values
    for lat, lon in tqdm(zip(latitudes, longitudes), total=len(latitudes), desc="Mapping values"):
    # Assuming the correct dimensions are 'y' and 'x' (replace these with actual names from data.coords)
    
        for i in range(n_inputs):
            tmp = data.sel(x=lon, y=lat, band=i, method='nearest').values
            vals[i].append(tmp)

    # Create a DataFrame with the band values
    # Create a DataFrame to store the band values
    df = pd.DataFrame()
    for i in range(n_inputs):
        df[names[i]] = vals[i]
    
    return df

# %%
# Constants
n_inputs = 28
names = ["B01", "B02", "B03", "B04", "B05", "B06", "B07", "B08", "B8A", "B11", "B12", "ndwi", "ndvi", "ndbi", 
        "B01 (pooled)", "B02 (pooled)", "B03 (pooled)", "B04 (pooled)", "B05 (pooled)", "B06 (pooled)", "B07 (pooled)", "B08 (pooled)", "B8A (pooled)", "B11 (pooled)", "B12 (pooled)", "ndwi (pooled)", "ndvi (pooled)", "ndbi (pooled)"]
UhiData_FileName = "Data/Training_data_uhi_index.csv"
satellite_data =  "Data/S2_median_fullBands_indeces.tiff"

# Open the GeoTIFF file
tiff_path = "Data/S2_median_fullBands_indeces.tiff"

# Read the bands from the GeoTIFF file
with rasterio.open(tiff_path) as src1:
    cols = [src1.read(i) for i in range(1, n_inputs+1)]

# %%
# Would be faster in a df
feature_data = map_satellite_data(satellite_data, UhiData_FileName)
# Out:
# Mapping values: 100%|██████████| 11229/11229 [08:38<00:00, 21.64it/s]

# %%
# Redo columns
feature_data["ndwi"] = (feature_data["B03"] - feature_data["B08"])/(feature_data["B03"] + feature_data["B08"]) #Normalized Difference Water Index
feature_data["ndbi"] = (feature_data["B11"] - feature_data["B08"])/(feature_data["B11"] + feature_data["B08"]) # Normalized Difference Buildup Index
feature_data["ndvi"] = (feature_data["B08"] - feature_data["B04"])/(feature_data["B08"] + feature_data["B04"]) #Normalized Difference Vegetation Index
feature_data["ndwi (pooled)"] = (feature_data["B03 (pooled)"] - feature_data["B08 (pooled)"])/(feature_data["B03 (pooled)"] + feature_data["B08 (pooled)"]) #Normalized Difference Water Index
feature_data["ndbi (pooled)"] = (feature_data["B11 (pooled)"] - feature_data["B08 (pooled)"])/(feature_data["B11 (pooled)"] + feature_data["B08 (pooled)"]) # Normalized Difference Buildup Index
feature_data["ndvi (pooled)"] = (feature_data["B08 (pooled)"] - feature_data["B04 (pooled)"])/(feature_data["B08 (pooled)"] + feature_data["B04 (pooled)"]) #Normalized Difference Vegetation Index

feature_data['ndvi'] = feature_data['ndvi'].replace([np.inf, -np.inf], np.nan) 
feature_data['ndwi'] = feature_data['ndwi'].replace([np.inf, -np.inf], np.nan) 
feature_data['ndbi'] = feature_data['ndbi'].replace([np.inf, -np.inf], np.nan)
feature_data['ndvi (pooled)'] = feature_data['ndvi (pooled)'].replace([np.inf, -np.inf], np.nan) 
feature_data['ndwi (pooled)'] = feature_data['ndwi (pooled)'].replace([np.inf, -np.inf], np.nan) 
feature_data['ndbi (pooled)'] = feature_data['ndbi (pooled)'].replace([np.inf, -np.inf], np.nan)

# %%
# Combining ground data and feature data into a single dataset.
ground_df = pd.read_csv(UhiData_FileName)

uhi_data = combine_two_datasets(ground_df,feature_data)

# %%
# Remove duplicate rows from the DataFrame based on specified columns and keep the first occurrence
columns_to_check = ['B01','B04','B06','B08','ndvi']
for col in columns_to_check:
    # Check if the value is a numpy array and has more than one dimension
    uhi_data[col] = uhi_data[col].apply(lambda x: tuple(x) if isinstance(x, np.ndarray) and x.ndim > 0 else x)

# Now remove duplicates
uhi_data = uhi_data.drop_duplicates(subset=columns_to_check, keep='first')
uhi_data.head()
# Out:
#    Longitude   Latitude          datetime  UHI Index    B01    B02     B03  \
# 0 -73.909167  40.813107  24-07-2021 15:53   1.030289  841.5  841.5  1053.0
# 2 -73.909215  40.812978  24-07-2021 15:53   1.023798  841.5  841.5   646.0
# 3 -73.909242  40.812908  24-07-2021 15:53   1.023798  841.5  841.5   625.0
# 4 -73.909257  40.812845  24-07-2021 15:53   1.021634  841.5  841.5   659.5
# 6 -73.909312  40.812710  24-07-2021 15:53   1.015143  841.5  841.5   551.5
#
#       B04     B05     B06  ...        B05 (pooled)        B06 (pooled)  \
# 0  1155.0  1206.0  1481.5  ...  1220.8703703703707  1428.3641975308642
# 2   823.0   777.0  1130.5  ...  1134.7777777777778   1396.148148148148
# 3   766.0   741.5  1130.5  ...  1165.3765432098771  1413.3148148148139
# 4   763.0   708.5  1077.5  ...  1197.7777777777776  1426.7469135802453
# 6   768.5   659.0  1077.5  ...  1082.1975308641972  1356.6790123456778
#
#          B07 (pooled)        B08 (pooled)        B8A (pooled)  \
# 0  1753.5802469135792  1869.7654320987654  1814.5370370370372
# 2   1812.469135802468  1948.9567901234568   1876.382716049383
# 3  1846.5679012345677  1988.7777777777778  1953.9691358024688
# 4   1871.851851851852  2020.4691358024688  2023.9629629629626
# 6  1823.4012345679012  1985.0925925925926  1991.2037037037037
#
#          B11 (pooled)        B12 (pooled)  ndwi (pooled) ndvi (pooled)  \
# 0  1927.7037037037044  1841.3209876543203      -0.308904      0.247049
# 2  2021.0740740740753  1793.4320987654314      -0.354534      0.292568
# 3   2069.808641975309  1796.4876543209875      -0.344815      0.284392
# 4   2102.641975308642  1816.3395061728395      -0.331936      0.272227
# 6   2068.808641975308  1777.5370370370372      -0.361310      0.300358
#
#   ndbi (pooled)
# 0      0.015257
# 2      0.018165
# 3      0.019965
# 4      0.019930
# 6      0.020651
#
# [5 rows x 32 columns]

# %%
# Load data, normalize distributions
model1_data = uhi_data[names + ['UHI Index']]
md1_data_std = model1_data.apply(lambda x: (x - x.mean()) / x.std(), axis=0) 
md1_data_std =md1_data_std.apply(lambda x: pd.to_numeric(x, errors = 'coerce'), axis=0) 

# Convert object columns to numeric
#for col in ['B02', 'B03', 'B05', 'B11', 'B02 (pooled)', 'B03 (pooled)', 'B05 (pooled)', 'B11 (pooled)']:
for col in names:
    na_count = md1_data_std[col].isna().sum()
    #print(f"Number of NaN values in {col} after conversion: {na_count}")
    
#print(md1_data_std.dtypes)

# %%
# Divide data into training and testing
X = md1_data_std.drop(columns=['UHI Index']).values
y = md1_data_std['UHI Index'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=123)
print(X_train.shape) 
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (5848, 28)
# (5848,)
# (2507, 28)
# (2507,)

# %%
# Model
model1 = Sequential([
    Dense(32, activation = 'relu', input_shape=(28,) ),
    Dropout(0.1),
    Dense(32, activation = 'relu'),
    Dropout(0.1),
    Dense(1, activation = 'linear'),
])
model1.compile(optimizer=Adam(learning_rate=0.001) , loss = "MSE" )
model1.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2105
# Epoch 2/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9056
# Epoch 3/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8627
# Epoch 4/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8621
# Epoch 5/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8619
# Epoch 6/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8256
# Epoch 7/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8196
# Epoch 8/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8270
# Epoch 9/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8114
# Epoch 10/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8080
# Epoch 11/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8027
# Epoch 12/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8372
# Epoch 13/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7874
# Epoch 14/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8095
# Epoch 15/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7925
# Epoch 16/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8158
# Epoch 17/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7954
# Epoch 18/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7763
# Epoch 19/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7720
# Epoch 20/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7830
# Epoch 21/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7688
# Epoch 22/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7765
# Epoch 23/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7477
# Epoch 24/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7544
# Epoch 25/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7622
# Epoch 26/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7397
# Epoch 27/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7540
# Epoch 28/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7420
# Epoch 29/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7539
# Epoch 30/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7306
# Epoch 31/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7616
# Epoch 32/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7181
# Epoch 33/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7470
# Epoch 34/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7549
# Epoch 35/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7274
# Epoch 36/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7347
# Epoch 37/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7274
# Epoch 38/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7483
# Epoch 39/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7386
# Epoch 40/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7498
# Epoch 41/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7326
# Epoch 42/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7490
# Epoch 43/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7397
# Epoch 44/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7404
# Epoch 45/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7414
# Epoch 46/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7207
# Epoch 47/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7224
# Epoch 48/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7523
# Epoch 49/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7325
# Epoch 50/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7334

# %%
print(f"MSE: {mean_squared_error(y_test , model1.predict(X_test))}")
print(f"r2: {r2_score(y_test, model1.predict(X_test))}")
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE: 0.7739499633973802
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# r2: 0.22736898960834884

# %%
y_lazy_pred = np.mean(y_test)*np.ones(len(y_test))
print(f'Lazy MSE: {mean_squared_error(y_test , y_lazy_pred)}')
print(f"Lazy r2: {r2_score(y_test, y_lazy_pred)}")
# Out:
# Lazy MSE: 1.0017070930211052
# Lazy r2: 0.0

# %%
md2_data_std = md1_data_std[['B01', 'B05' , 'B08', 'B11','ndwi' , 'ndvi', 'ndbi' , 'UHI Index']]

X2 = md2_data_std.drop(columns=['UHI Index']).values
y2 = md2_data_std['UHI Index'].values


X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.3,random_state=123)
print(X_train.shape) 
print(y_test.shape)
# Out:
# (5847, 10)
# (2507,)

# %%
#model using only the features used in the sample notebook 

model2 = Sequential([
    #Dense(512 , input_shape=(7,), activation='relu'),
    #Dense(128, activation = 'relu'),
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2), 
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2),
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2),
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2),
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2),
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2),
    Dense(30, activation = 'linear'),
    Dense(30, activation = 'relu'),
    #Dense(64 , activation = 'relu'),
    #Dense(32, activation = 'relu'),
    #Dense(16, activation = 'relu' ),
    Dense(1, activation = 'linear' ) #Output continous variable UHI index 
])

model2.compile(optimizer= 'adam' , loss = "MSE" )

model2.fit(X2_train, y2_train, epochs=50 ,batch_size=10, validation_split=0.2 ) 

#model_lassoreg.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.9606 - val_loss: 1.1133
# Epoch 2/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.0727 - val_loss: 0.9809
# Epoch 3/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9482 - val_loss: 0.9687
# Epoch 4/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9465 - val_loss: 0.9452
# Epoch 5/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.9378 - val_loss: 0.9232
# Epoch 6/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.9059 - val_loss: 0.9438
# Epoch 7/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9422 - val_loss: 0.9455
# Epoch 8/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9184 - val_loss: 0.9344
# Epoch 9/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9005 - val_loss: 0.9348
# Epoch 10/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9500 - val_loss: 0.9273
# Epoch 11/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9423 - val_loss: 1.0096
# Epoch 12/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9322 - val_loss: 0.9351
# Epoch 13/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.9199 - val_loss: 0.9153
# Epoch 14/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.8767 - val_loss: 0.9295
# Epoch 15/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9343 - val_loss: 0.9251
# Epoch 16/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.9142 - val_loss: 0.9462
# Epoch 17/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.9083 - val_loss: 0.9186
# Epoch 18/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9326 - val_loss: 0.9320
# Epoch 19/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9198 - val_loss: 0.9337
# Epoch 20/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9305 - val_loss: 0.9290
# Epoch 21/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9065 - val_loss: 0.9313
# Epoch 22/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9077 - val_loss: 0.9141
# Epoch 23/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9081 - val_loss: 0.9203
# Epoch 24/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.8852 - val_loss: 0.9253
# Epoch 25/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.8922 - val_loss: 0.9251
# Epoch 26/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9023 - val_loss: 0.9183
# Epoch 27/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9161 - val_loss: 0.9375
# Epoch 28/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9196 - val_loss: 0.9433
# Epoch 29/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.8999 - val_loss: 0.9261
# Epoch 30/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.8870 - val_loss: 0.9333
# Epoch 31/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.8890 - val_loss: 0.9393
# Epoch 32/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9482 - val_loss: 0.9370
# Epoch 33/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9169 - val_loss: 0.9265
# Epoch 34/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.8957 - val_loss: 0.9211
# Epoch 35/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9138 - val_loss: 0.9209
# Epoch 36/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.8841 - val_loss: 0.9167
# Epoch 37/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9094 - val_loss: 0.9134
# Epoch 38/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9088 - val_loss: 0.9062
# Epoch 39/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.8911 - val_loss: 0.9315
# Epoch 40/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9013 - val_loss: 0.9153
# Epoch 41/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9095 - val_loss: 0.9129
# Epoch 42/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.8897 - val_loss: 0.9202
# Epoch 43/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9173 - val_loss: 0.9098
# Epoch 44/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.9000 - val_loss: 0.9105
# Epoch 45/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.8940 - val_loss: 0.9102
# Epoch 46/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9052 - val_loss: 0.9123
# Epoch 47/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.8841 - val_loss: 0.9256
# Epoch 48/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.8830 - val_loss: 0.9304
# Epoch 49/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9224 - val_loss: 0.9045
# Epoch 50/50
# 468/468 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.8907 - val_loss: 0.9221

# %%
print(r2_score(y_test, model2.predict(X2_test)))
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 0.11947834753868347

# %%
#Model with a regularizer to increas epocs and avoid overfitting

from tensorflow.keras import regularizers



model_lassoreg = Sequential([
    Dense(512 , input_shape=(10,), activation='relu'),
    Dropout(0.2),
    Dense(128, activation = 'linear' ,
        kernel_regularizer=regularizers.l2(0.01)),
    #Dense(30, activation = 'relu'),
    Dense(64 , activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.1)),
    Dense(32, activation = 'linear',
         kernel_regularizer=regularizers.l2(0.01)),
    Dense(16, activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.1)),
    Dense(1, activation = 'linear' ) #Output continous variable UHI index 
])


model_lassoreg.compile(optimizer= 'adam' , loss = "MSE" )

model_lassoreg.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 55.2669 - val_loss: 4.3807
# Epoch 2/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0770 - val_loss: 1.1767
# Epoch 3/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1342 - val_loss: 1.1101
# Epoch 4/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0740 - val_loss: 1.1024
# Epoch 5/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1046 - val_loss: 1.1014
# Epoch 6/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0829 - val_loss: 1.0996
# Epoch 7/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0937 - val_loss: 1.1005
# Epoch 8/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0682 - val_loss: 1.0999
# Epoch 9/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0968 - val_loss: 1.0991
# Epoch 10/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1185 - val_loss: 1.1013
# Epoch 11/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1217 - val_loss: 1.0993
# Epoch 12/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1251 - val_loss: 1.1006
# Epoch 13/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1132 - val_loss: 1.1003
# Epoch 14/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0895 - val_loss: 1.0995
# Epoch 15/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0974 - val_loss: 1.1004
# Epoch 16/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0847 - val_loss: 1.0998
# Epoch 17/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0777 - val_loss: 1.1009
# Epoch 18/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0787 - val_loss: 1.1000
# Epoch 19/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1035 - val_loss: 1.0992
# Epoch 20/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0836 - val_loss: 1.1007
# Epoch 21/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0754 - val_loss: 1.0997
# Epoch 22/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0833 - val_loss: 1.0989
# Epoch 23/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0676 - val_loss: 1.0994
# Epoch 24/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0875 - val_loss: 1.0997
# Epoch 25/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1052 - val_loss: 1.1002
# Epoch 26/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0856 - val_loss: 1.1009
# Epoch 27/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1038 - val_loss: 1.0984
# Epoch 28/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1029 - val_loss: 1.0996
# Epoch 29/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1026 - val_loss: 1.0992
# Epoch 30/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0940 - val_loss: 1.1007
# Epoch 31/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1059 - val_loss: 1.0999
# Epoch 32/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0917 - val_loss: 1.0995
# Epoch 33/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1116 - val_loss: 1.0992
# Epoch 34/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0972 - val_loss: 1.0998
# Epoch 35/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0608 - val_loss: 1.1007
# Epoch 36/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1053 - val_loss: 1.0992
# Epoch 37/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0749 - val_loss: 1.0994
# Epoch 38/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1164 - val_loss: 1.0995
# Epoch 39/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1254 - val_loss: 1.0996
# Epoch 40/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0856 - val_loss: 1.1002
# Epoch 41/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0902 - val_loss: 1.0990
# Epoch 42/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0914 - val_loss: 1.0990
# Epoch 43/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0671 - val_loss: 1.0995
# Epoch 44/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0682 - val_loss: 1.0983
# Epoch 45/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0915 - val_loss: 1.0995
# Epoch 46/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1230 - val_loss: 1.0992
# Epoch 47/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0965 - val_loss: 1.0996
# Epoch 48/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0770 - val_loss: 1.0997
# Epoch 49/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0925 - val_loss: 1.0998
# Epoch 50/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1310 - val_loss: 1.1010
# Epoch 51/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0844 - val_loss: 1.0995
# Epoch 52/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0969 - val_loss: 1.0994
# Epoch 53/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0846 - val_loss: 1.1003
# Epoch 54/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0905 - val_loss: 1.0984
# Epoch 55/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0961 - val_loss: 1.0996
# Epoch 56/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0849 - val_loss: 1.0994
# Epoch 57/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1058 - val_loss: 1.0994
# Epoch 58/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1202 - val_loss: 1.0997
# Epoch 59/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1141 - val_loss: 1.0996
# Epoch 60/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1066 - val_loss: 1.0994
# Epoch 61/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0633 - val_loss: 1.0994
# Epoch 62/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0865 - val_loss: 1.0992
# Epoch 63/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0883 - val_loss: 1.1002
# Epoch 64/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0911 - val_loss: 1.0995
# Epoch 65/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0570 - val_loss: 1.1005
# Epoch 66/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0837 - val_loss: 1.0987
# Epoch 67/100
# 138/168 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0607
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 25
#       7 model_lassoreg = Sequential([
#       8     Dense(512 , input_shape=(10,), activation='relu'),
#       9     Dropout(0.2),
#    (...)
#      19     Dense(1, activation = 'linear' ) #Output continous variable UHI index
#      20 ])
#      23 model_lassoreg.compile(optimizer= 'adam' , loss = "MSE" )
# ---> 25 model_lassoreg.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:249, in AtomicFunction.call_flat(self, *args)
#     242 with InterpolateRuntimeError(self):
#     243   with ops.control_dependencies(self._call_options.control_captures):
#     244     # The caller must use record_operation to record this operation in the
#     245     # eager case, so we enforce the same requirement for the non-eager
#     246     # case by explicitly pausing recording. We don't have a gradient
#     247     # registered for PartitionedCall, so recording this operation confuses
#     248     # forwardprop code (GradientTape manages to ignore it).
# --> 249     with record.stop_recording():
#     250       if self._bound_context.executing_eagerly():
#     251         outputs = self._bound_context.call_function(
#     252             self.name,
#     253             list(args),
#     254             len(self.function_type.flat_outputs),
#     255         )
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/contextlib.py:281, in contextmanager.<locals>.helper(*args, **kwds)
#     279 @wraps(func)
#     280 def helper(*args, **kwds):
# --> 281     return _GeneratorContextManager(func, args, kwds)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/contextlib.py:102, in _GeneratorContextManagerBase.__init__(self, func, args, kwds)
#      99 class _GeneratorContextManagerBase:
#     100     """Shared functionality for @contextmanager and @asynccontextmanager."""
# --> 102     def __init__(self, func, args, kwds):
#     103         self.gen = func(*args, **kwds)
#     104         self.func, self.args, self.kwds = func, args, kwds
#
# KeyboardInterrupt:

# %%
print(r2_score(y_test, model_lassoreg.predict(X_test)))
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 0.1269695466287537

# %%
#attempt at helping the network find nonlinear relations
import itertools

md3_data = md1_data_std.copy()
feature_list = md3_data.drop(columns=['UHI Index']).columns.tolist()

column_combinations = itertools.combinations(feature_list, 2)
print(columns_to_check)
for col1, col2 in column_combinations:
    new_col_name = f'{col1}_{col2}'  # Name for the new column
    md3_data[new_col_name ] = md3_data[col1] * md3_data[col2]  # Multiply the column



len(feature_list)
md3_data.columns.to_list()
#md3_data.shape
# Out:
# ['B01', 'B04', 'B06', 'B08', 'ndvi']
# ['B01',
#  'B02',
#  'B03',
#  'B04',
#  'B05',
#  'B08',
#  'B11',
#  'ndwi',
#  'ndvi',
#  'ndbi',
#  'UHI Index',
#  'B01_B02',
#  'B01_B03',
#  'B01_B04',
#  'B01_B05',
#  'B01_B08',
#  'B01_B11',
#  'B01_ndwi',
#  'B01_ndvi',
#  'B01_ndbi',
#  'B02_B03',
#  'B02_B04',
#  'B02_B05',
#  'B02_B08',
#  'B02_B11',
#  'B02_ndwi',
#  'B02_ndvi',
#  'B02_ndbi',
#  'B03_B04',
#  'B03_B05',
#  'B03_B08',
#  'B03_B11',
#  'B03_ndwi',
#  'B03_ndvi',
#  'B03_ndbi',
#  'B04_B05',
#  'B04_B08',
#  'B04_B11',
#  'B04_ndwi',
#  'B04_ndvi',
#  'B04_ndbi',
#  'B05_B08',
#  'B05_B11',
#  'B05_ndwi',
#  'B05_ndvi',
#  'B05_ndbi',
#  'B08_B11',
#  'B08_ndwi',
#  'B08_ndvi',
#  'B08_ndbi',
#  'B11_ndwi',
#  'B11_ndvi',
#  'B11_ndbi',
#  'ndwi_ndvi',
#  'ndwi_ndbi',
#  'ndvi_ndbi']

# %%
X3 = md3_data.drop(columns=['UHI Index']).values
y3 = md3_data['UHI Index'].values


X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.2,random_state=125)
print(X3_train.shape) 
print(y3_test.shape)
# Out:
# (6683, 55)
# (1671,)

# %%
from tensorflow.keras import regularizers


quartic_md_reg = Sequential([
    Dense(2048 , input_shape=(55,), activation='linear'),
    Dropout(0.2),
    Dense(1024 , activation='relu'),
    Dropout(0.2),
    Dense(128, activation = 'linear' ,
        kernel_regularizer=regularizers.l2(0.5)),
    Dense(64 , activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(32, activation = 'linear',
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(16, activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(1, activation = 'linear' ) #Output continous variable UHI index 
])

#this architecture achieves the same result as the original DNN. 
'''quartic_md_reg = Sequential([
    Dense(2048 , input_shape=(55,), activation='linear'),
    Dropout(0.2),
    Dense(1024 , activation='relu'),
    Dropout(0.2),
    Dense(128, activation = 'linear' ,
        kernel_regularizer=regularizers.l2(0.5)),
    Dense(64 , activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(32, activation = 'linear',
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(16, activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(1, activation = 'linear' ) #Output continous variable UHI index 
])''' 

quartic_md_reg.compile(optimizer= 'adam' , loss = "MSE" )

quartic_md_reg.fit(X3_train, y3_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 47.9798 - val_loss: 1.2515
# Epoch 2/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0417 - val_loss: 1.0741
# Epoch 3/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9677 - val_loss: 1.0730
# Epoch 4/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 1.0026 - val_loss: 1.0732
# Epoch 5/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 1.0141 - val_loss: 1.0730
# Epoch 6/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0130 - val_loss: 1.0731
# Epoch 7/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0222 - val_loss: 1.0733
# Epoch 8/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9925 - val_loss: 1.0731
# Epoch 9/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.0222 - val_loss: 1.0735
# Epoch 10/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0239 - val_loss: 1.0730
# Epoch 11/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9936 - val_loss: 1.0730
# Epoch 12/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9995 - val_loss: 1.0732
# Epoch 13/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9659 - val_loss: 1.0731
# Epoch 14/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0027 - val_loss: 1.0730
# Epoch 15/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9696 - val_loss: 1.0737
# Epoch 16/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9671 - val_loss: 1.0735
# Epoch 17/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9900 - val_loss: 1.0731
# Epoch 18/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.0052 - val_loss: 1.0733
# Epoch 19/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.9782 - val_loss: 1.0730
# Epoch 20/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9958 - val_loss: 1.0731
# Epoch 21/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.9904 - val_loss: 1.0733
# Epoch 22/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9728 - val_loss: 1.0732
# Epoch 23/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 1.0239 - val_loss: 1.0731
# Epoch 24/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 1.0012 - val_loss: 1.0732
# Epoch 25/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 1.0038 - val_loss: 1.0731
# Epoch 26/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 1.0054 - val_loss: 1.0731
# Epoch 27/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9888 - val_loss: 1.0732
# Epoch 28/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0073 - val_loss: 1.0731
# Epoch 29/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9898 - val_loss: 1.0731
# Epoch 30/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0029 - val_loss: 1.0731
# Epoch 31/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.9928 - val_loss: 1.0731
# Epoch 32/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.9999 - val_loss: 1.0731
# Epoch 33/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9854 - val_loss: 1.0731
# Epoch 34/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9942 - val_loss: 1.0731
# Epoch 35/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9804 - val_loss: 1.0731
# Epoch 36/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0232 - val_loss: 1.0731
# Epoch 37/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0169 - val_loss: 1.0731
# Epoch 38/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9942 - val_loss: 1.0731
# Epoch 39/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9776 - val_loss: 1.0731
# Epoch 40/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9725 - val_loss: 1.0731
# Epoch 41/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0046 - val_loss: 1.0731
# Epoch 42/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0074 - val_loss: 1.0732
# Epoch 43/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0139 - val_loss: 1.0731
# Epoch 44/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9928 - val_loss: 1.0731
# Epoch 45/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9967 - val_loss: 1.0731
# Epoch 46/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9959 - val_loss: 1.0734
# Epoch 47/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.0118 - val_loss: 1.0731
# Epoch 48/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0092 - val_loss: 1.0731
# Epoch 49/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.9807 - val_loss: 1.0731
# Epoch 50/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9765 - val_loss: 1.0731

# %%
print(r2_score(y3_test, quartic_md_reg.predict(X3_test)))
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# -0.0002088499122305798
