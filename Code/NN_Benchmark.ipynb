# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# Visualization
import matplotlib.pyplot as plt
#import seaborn as sns

# Data Science
import numpy as np
import pandas as pd

# Multi-dimensional arrays and datasets
import xarray as xr

# Geospatial raster data handling
import rioxarray as rxr

# Geospatial data analysis
#import geopandas as gpd

# Geospatial operations
import rasterio
from rasterio import windows  
from rasterio import features  
from rasterio import warp
from rasterio.warp import transform_bounds 
from rasterio.windows import from_bounds 

# Image Processing
from PIL import Image

# Coordinate transformations
from pyproj import Proj, Transformer, CRS

# Feature Engineering
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Machine Learning
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# Planetary Computer Tools
import pystac_client
import planetary_computer as pc
from pystac.extensions.eo import EOExtension as eo

# Others
import os
from tqdm import tqdm

# %%
# Open the GeoTIFF file
tiff_path = "Data/S2_median_fullBands_indeces.tiff"

# Read the bands from the GeoTIFF file
with rasterio.open(tiff_path) as src1:
    B01 = src1.read(1)  # Band [B01]
    B02 = src1.read(2)  # Band [B02]
    B03 = src1.read(3)  # Band [B03]
    B04 = src1.read(4)  # Band [B04]
    B05 = src1.read(5) #Band [B05]
    B06 = src1.read(6) # Band [B06]
    B07 = src1.read(7) # Band [B07]
    B08 = src1.read(8) # Band [B08]
    B8A = src1.read(9) # Band [B8A]
    B11 = src1.read(10) # Band [B11]
    B12 = src1.read(11) # Band [B12]
    ndwi = src1.read(12) #water index 
    ndvi = src1.read(13) #vegetation index
    ndbi = src1.read(14) #building index

# %%
# Extracts satellite band values from a GeoTIFF based on coordinates from a csv file and returns them in a DataFrame.

def map_satellite_data(tiff_path, csv_path):
    
    # Load the GeoTIFF data
    data = rxr.open_rasterio(tiff_path)
    tiff_crs = data.rio.crs

    # Read the Excel file using pandas
    df = pd.read_csv(csv_path)
    latitudes = df['Latitude'].values
    longitudes = df['Longitude'].values

    # 3. Convert lat/long to the GeoTIFF's CRS
    # Create a Proj object for EPSG:4326 (WGS84 - lat/long) and the GeoTIFF's CRS
    proj_wgs84 = Proj(init='epsg:4326')  # EPSG:4326 is the common lat/long CRS
    proj_tiff = Proj(tiff_crs)
    
    # Create a transformer object
    transformer = Transformer.from_proj(proj_wgs84, proj_tiff)

    B01_values = []
    B02_values = []
    B03_values = []
    B04_values = []
    B05_values = []
    B06_values = []
    B07_values = []
    B08_values = []
    B8A_values = []
    B11_values = []
    B12_values = []
    ndwi_values = []
    ndvi_values = []
    ndbi_values= []



# Iterate over the latitudes and longitudes, and extract the corresponding band values
    for lat, lon in tqdm(zip(latitudes, longitudes), total=len(latitudes), desc="Mapping values"):
    # Assuming the correct dimensions are 'y' and 'x' (replace these with actual names from data.coords)
    
        B01_value = data.sel(x=lon, y=lat,  band=1, method="nearest").values
        B01_values.append(B01_value)

        B02_value = data.sel(x=lon, y=lat,  band=2, method="nearest").values
        B02_values.append(B02_value)

        B03_value = data.sel(x=lon, y=lat,  band=3, method="nearest").values
        B03_values.append(B03_value)
    
        B04_value = data.sel(x=lon, y=lat, band=5, method="nearest").values
        B04_values.append(B04_value)

        B05_value = data.sel(x=lon, y=lat,  band=5, method="nearest").values
        B05_values.append(B05_value)
        
        B06_value = data.sel(x=lon, y=lat, band=6, method="nearest").values
        B06_values.append(B06_value)

        B07_value = data.sel(x=lon, y=lat,  band=7, method="nearest").values
        B07_values.append(B07_value)
    
        B08_value = data.sel(x=lon, y=lat, band=8, method="nearest").values
        B08_values.append(B08_value)

        B8A_value = data.sel(x=lon, y=lat, band=9, method="nearest").values
        B8A_values.append(B8A_value)

        B11_value = data.sel(x=lon, y=lat, band=10, method="nearest").values
        B11_values.append(B11_value)

        B12_value = data.sel(x=lon, y=lat, band=11, method="nearest").values
        B12_values.append(B12_value)

        ndwi_value = data.sel(x=lon, y=lat, band=12, method="nearest").values
        ndwi_values.append(ndwi_value)

        ndvi_value = data.sel(x=lon, y=lat, band=13, method="nearest").values
        ndvi_values.append(ndvi_value)

        ndbi_value = data.sel(x=lon, y=lat, band=14, method="nearest").values
        ndbi_values.append(ndbi_value)


    # Create a DataFrame with the band values
    # Create a DataFrame to store the band values
    df = pd.DataFrame()
    df['B01'] = B01_values
    df['B02'] = B02_values
    df['B03'] = B03_values
    df['B04'] = B04_values
    df['B05'] = B05_values
    df['B06'] = B06_values
    df['B07'] = B07_values
    df['B08'] = B08_values
    df['B8A'] = B8A_values
    df['B11'] = B11_values
    df['B12'] = B12_values
    df['ndwi'] = ndwi_values
    df['ndvi'] = ndvi_values
    df['ndbi'] = ndbi_values
    
    return df

# %% [markdown]
# ### Sentinel-2 Bands Summary
# The following list of common bands can be loaded by the Open Data Cube (ODC) stac command.<br><br>
# B01 = Coastal Aerosol = 60m <br>
# B02 = Blue = 10m <br>
# B03 = Green = 10m <br>
# B04 = Red = 10m <br>
# B05 = Red Edge (704 nm) = 20m <br>
# B06 = Red Edge (740 nm) = 20m <br>
# B07 = Red Edge (780 nm) = 20m <br>
# B08 = NIR (833 nm) = 10m <br>
# B8A = NIR (narrow 864 nm) = 20m <br>
# B11 = SWIR (1.6 um) = 20m <br>
# B12 = SWIR (2.2 um) = 20m

# %%
#this would be faster if I didn't import the indices from the tiff file and just redid them with pandas

UhiData_FileName = "/Users/jorgehernandez/Desktop/COS513/CourseProject/Code/Data/Training_data_uhi_index_2025-02-18.csv"
satellite_data =  "/Users/jorgehernandez/Desktop/COS513/CourseProject/Code/Data/S2_median_fullBands_indeces.tiff"

feature_data = map_satellite_data(satellite_data, UhiData_FileName)
# Out:
# Mapping values: 100%|██████████| 11229/11229 [01:01<00:00, 181.67it/s]

# %%
#feature_data = median.to_dataframe().reset_index()
#There seems to be an error in which the index data is transferred wrong, all the indeces have the same values
#this is why I redo the columns here 
feature_data["ndwi"] = (feature_data["B03"] - feature_data["B08"])/(feature_data["B03"] + feature_data["B08"]) #Normalized Difference Water Index
feature_data["ndbi"] = (feature_data["B11"] - feature_data["B08"])/(feature_data["B11"] + feature_data["B08"]) # Normalized Difference Buildup Index
feature_data["ndvi"] = (feature_data["B08"] - feature_data["B04"])/(feature_data["B08"] + feature_data["B04"]) #Normalized Difference Vegetation Index


feature_data['ndvi'] = feature_data['ndvi'].replace([np.inf, -np.inf], np.nan) 
feature_data['ndwi'] = feature_data['ndwi'].replace([np.inf, -np.inf], np.nan) 
feature_data['ndbi'] = feature_data['ndbi'].replace([np.inf, -np.inf], np.nan) 


#nan_count = np.isnan(feature_data['ndwi'].to_numpy()).sum()
#print("Number of NaN values:", nan_count)  # Output: Number of NaN values: 1
#print(feature_data['ndwi'])


#Had to check manually that all elements in the indices where numeric. np.isinf and np.isnan dont work for some reason. 
#really annoying 
#for ele in feature_data['ndvi']:
 # print(ele)

# %%
def combine_two_datasets(dataset1,dataset2):
    '''
    Returns a  vertically concatenated dataset.
    Attributes:
    dataset1 - Dataset 1 to be combined 
    dataset2 - Dataset 2 to be combined
    '''
    
    data = pd.concat([dataset1,dataset2], axis=1)
    return data

# %%
# Combining ground data and feature data into a single dataset.
ground_df = pd.read_csv(UhiData_FileName)

uhi_data = combine_two_datasets(ground_df,feature_data)
uhi_data
# Out:
#        Longitude   Latitude          datetime  UHI Index    B01     B02  \
# 0     -73.909167  40.813107  24-07-2021 15:53   1.030289  841.5  1053.0
# 1     -73.909187  40.813045  24-07-2021 15:53   1.030289  841.5  1053.0
# 2     -73.909215  40.812978  24-07-2021 15:53   1.023798  841.5   646.0
# 3     -73.909242  40.812908  24-07-2021 15:53   1.023798  841.5   625.0
# 4     -73.909257  40.812845  24-07-2021 15:53   1.021634  841.5   659.5
# ...          ...        ...               ...        ...    ...     ...
# 11224 -73.957050  40.790333  24-07-2021 15:57   0.972470  462.5   491.0
# 11225 -73.957063  40.790308  24-07-2021 15:57   0.972470  462.5   506.5
# 11226 -73.957093  40.790270  24-07-2021 15:57   0.981124  462.5   506.5
# 11227 -73.957112  40.790253  24-07-2021 15:59   0.981245  462.5   506.5
# 11228 -73.957128  40.790237  24-07-2021 15:59   0.983408  462.5   640.0
#
#           B03     B04     B05     B06     B07     B08     B8A     B11     B12  \
# 0      1155.0  1481.5  1481.5  1660.5  1721.0  1832.0  1709.0  1792.0  1495.5
# 1      1155.0  1481.5  1481.5  1660.5  1721.0  1832.0  1709.0  1792.0  1495.5
# 2       823.0  1130.5  1130.5  1883.0  2117.5  2241.0  2251.0  1548.0  1135.0
# 3       766.0  1130.5  1130.5  1883.0  2117.5  2200.0  2251.0  1548.0  1135.0
# 4       763.0  1077.5  1077.5  1783.0  2042.0  2161.0  2186.0  1617.5  1207.5
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 11224   725.5   999.0   999.0  2612.0  3111.5  3152.0  3446.5  1925.0  1072.5
# 11225   741.5   999.0   999.0  2612.0  3111.5  3572.0  3446.5  1925.0  1072.5
# 11226   741.5   999.0   999.0  2612.0  3111.5  3572.0  3446.5  1925.0  1072.5
# 11227   741.5   999.0   999.0  2612.0  3111.5  3572.0  3446.5  1925.0  1072.5
# 11228   835.0  1014.5  1014.5  2755.0  3407.5  3341.0  3487.0  2106.5  1182.5
#
#            ndwi      ndvi      ndbi
# 0     -0.226649  0.105779 -0.011038
# 1     -0.226649  0.105779 -0.011038
# 2     -0.462794  0.329379 -0.182898
# 3     -0.483479  0.321123 -0.173959
# 4     -0.478112  0.334568 -0.143840
# ...         ...       ...       ...
# 11224 -0.625790  0.518670 -0.241678
# 11225 -0.656196  0.562897 -0.299618
# 11226 -0.656196  0.562897 -0.299618
# 11227 -0.656196  0.562897 -0.299618
# 11228 -0.600096  0.534152 -0.226618
#
# [11229 rows x 18 columns]

# %%
# Combining ground data and feature data into a single dataset.
ground_df = pd.read_csv(UhiData_FileName)

uhi_data = combine_two_datasets(ground_df,feature_data)
uhi_data
# Out:
#        Longitude   Latitude          datetime  UHI Index    B01     B02  \
# 0     -73.909167  40.813107  24-07-2021 15:53   1.030289  841.5  1053.0
# 1     -73.909187  40.813045  24-07-2021 15:53   1.030289  841.5  1053.0
# 2     -73.909215  40.812978  24-07-2021 15:53   1.023798  841.5   646.0
# 3     -73.909242  40.812908  24-07-2021 15:53   1.023798  841.5   625.0
# 4     -73.909257  40.812845  24-07-2021 15:53   1.021634  841.5   659.5
# ...          ...        ...               ...        ...    ...     ...
# 11224 -73.957050  40.790333  24-07-2021 15:57   0.972470  462.5   491.0
# 11225 -73.957063  40.790308  24-07-2021 15:57   0.972470  462.5   506.5
# 11226 -73.957093  40.790270  24-07-2021 15:57   0.981124  462.5   506.5
# 11227 -73.957112  40.790253  24-07-2021 15:59   0.981245  462.5   506.5
# 11228 -73.957128  40.790237  24-07-2021 15:59   0.983408  462.5   640.0
#
#           B03     B04     B05     B06     B07     B08     B8A     B11     B12  \
# 0      1155.0  1481.5  1481.5  1660.5  1721.0  1832.0  1709.0  1792.0  1495.5
# 1      1155.0  1481.5  1481.5  1660.5  1721.0  1832.0  1709.0  1792.0  1495.5
# 2       823.0  1130.5  1130.5  1883.0  2117.5  2241.0  2251.0  1548.0  1135.0
# 3       766.0  1130.5  1130.5  1883.0  2117.5  2200.0  2251.0  1548.0  1135.0
# 4       763.0  1077.5  1077.5  1783.0  2042.0  2161.0  2186.0  1617.5  1207.5
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 11224   725.5   999.0   999.0  2612.0  3111.5  3152.0  3446.5  1925.0  1072.5
# 11225   741.5   999.0   999.0  2612.0  3111.5  3572.0  3446.5  1925.0  1072.5
# 11226   741.5   999.0   999.0  2612.0  3111.5  3572.0  3446.5  1925.0  1072.5
# 11227   741.5   999.0   999.0  2612.0  3111.5  3572.0  3446.5  1925.0  1072.5
# 11228   835.0  1014.5  1014.5  2755.0  3407.5  3341.0  3487.0  2106.5  1182.5
#
#            ndwi      ndvi      ndbi
# 0     -0.226649  0.105779 -0.011038
# 1     -0.226649  0.105779 -0.011038
# 2     -0.462794  0.329379 -0.182898
# 3     -0.483479  0.321123 -0.173959
# 4     -0.478112  0.334568 -0.143840
# ...         ...       ...       ...
# 11224 -0.625790  0.518670 -0.241678
# 11225 -0.656196  0.562897 -0.299618
# 11226 -0.656196  0.562897 -0.299618
# 11227 -0.656196  0.562897 -0.299618
# 11228 -0.600096  0.534152 -0.226618
#
# [11229 rows x 18 columns]

# %%
# Combining ground data and feature data into a single dataset.
ground_df = pd.read_csv(UhiData_FileName)

uhi_data = combine_two_datasets(ground_df,feature_data)
uhi_data
# Out:
#        Longitude   Latitude          datetime  UHI Index    B01     B02  \
# 0     -73.909167  40.813107  24-07-2021 15:53   1.030289  841.5  1053.0
# 1     -73.909187  40.813045  24-07-2021 15:53   1.030289  841.5  1053.0
# 2     -73.909215  40.812978  24-07-2021 15:53   1.023798  841.5   646.0
# 3     -73.909242  40.812908  24-07-2021 15:53   1.023798  841.5   625.0
# 4     -73.909257  40.812845  24-07-2021 15:53   1.021634  841.5   659.5
# ...          ...        ...               ...        ...    ...     ...
# 11224 -73.957050  40.790333  24-07-2021 15:57   0.972470  462.5   491.0
# 11225 -73.957063  40.790308  24-07-2021 15:57   0.972470  462.5   506.5
# 11226 -73.957093  40.790270  24-07-2021 15:57   0.981124  462.5   506.5
# 11227 -73.957112  40.790253  24-07-2021 15:59   0.981245  462.5   506.5
# 11228 -73.957128  40.790237  24-07-2021 15:59   0.983408  462.5   640.0
#
#           B03     B04     B05     B06     B07     B08     B8A     B11     B12  \
# 0      1155.0  1481.5  1481.5  1660.5  1721.0  1832.0  1709.0  1792.0  1495.5
# 1      1155.0  1481.5  1481.5  1660.5  1721.0  1832.0  1709.0  1792.0  1495.5
# 2       823.0  1130.5  1130.5  1883.0  2117.5  2241.0  2251.0  1548.0  1135.0
# 3       766.0  1130.5  1130.5  1883.0  2117.5  2200.0  2251.0  1548.0  1135.0
# 4       763.0  1077.5  1077.5  1783.0  2042.0  2161.0  2186.0  1617.5  1207.5
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 11224   725.5   999.0   999.0  2612.0  3111.5  3152.0  3446.5  1925.0  1072.5
# 11225   741.5   999.0   999.0  2612.0  3111.5  3572.0  3446.5  1925.0  1072.5
# 11226   741.5   999.0   999.0  2612.0  3111.5  3572.0  3446.5  1925.0  1072.5
# 11227   741.5   999.0   999.0  2612.0  3111.5  3572.0  3446.5  1925.0  1072.5
# 11228   835.0  1014.5  1014.5  2755.0  3407.5  3341.0  3487.0  2106.5  1182.5
#
#            ndwi      ndvi      ndbi
# 0     -0.226649  0.105779 -0.011038
# 1     -0.226649  0.105779 -0.011038
# 2     -0.462794  0.329379 -0.182898
# 3     -0.483479  0.321123 -0.173959
# 4     -0.478112  0.334568 -0.143840
# ...         ...       ...       ...
# 11224 -0.625790  0.518670 -0.241678
# 11225 -0.656196  0.562897 -0.299618
# 11226 -0.656196  0.562897 -0.299618
# 11227 -0.656196  0.562897 -0.299618
# 11228 -0.600096  0.534152 -0.226618
#
# [11229 rows x 18 columns]

# %%
# Remove duplicate rows from the DataFrame based on specified columns and keep the first occurrence
columns_to_check = ['B01','B04','B06','B08','ndvi']
for col in columns_to_check:
    # Check if the value is a numpy array and has more than one dimension
    uhi_data[col] = uhi_data[col].apply(lambda x: tuple(x) if isinstance(x, np.ndarray) and x.ndim > 0 else x)

# Now remove duplicates
uhi_data = uhi_data.drop_duplicates(subset=columns_to_check, keep='first')
uhi_data.head()

uhi_data
# Out:
#        Longitude   Latitude          datetime  UHI Index    B01     B02  \
# 0     -73.909167  40.813107  24-07-2021 15:53   1.030289  841.5  1053.0
# 2     -73.909215  40.812978  24-07-2021 15:53   1.023798  841.5   646.0
# 3     -73.909242  40.812908  24-07-2021 15:53   1.023798  841.5   625.0
# 4     -73.909257  40.812845  24-07-2021 15:53   1.021634  841.5   659.5
# 6     -73.909312  40.812710  24-07-2021 15:53   1.015143  841.5   551.5
# ...          ...        ...               ...        ...    ...     ...
# 11219 -73.956957  40.790503  24-07-2021 15:57   0.974633  403.0   325.0
# 11220 -73.956973  40.790482  24-07-2021 15:57   0.976797  403.0   318.5
# 11223 -73.957038  40.790360  24-07-2021 15:57   0.972470  462.5   491.0
# 11225 -73.957063  40.790308  24-07-2021 15:57   0.972470  462.5   506.5
# 11228 -73.957128  40.790237  24-07-2021 15:59   0.983408  462.5   640.0
#
#           B03     B04     B05     B06     B07     B08     B8A     B11     B12  \
# 0      1155.0  1481.5  1481.5  1660.5  1721.0  1832.0  1709.0  1792.0  1495.5
# 2       823.0  1130.5  1130.5  1883.0  2117.5  2241.0  2251.0  1548.0  1135.0
# 3       766.0  1130.5  1130.5  1883.0  2117.5  2200.0  2251.0  1548.0  1135.0
# 4       763.0  1077.5  1077.5  1783.0  2042.0  2161.0  2186.0  1617.5  1207.5
# 6       768.5  1077.5  1077.5  1783.0  2042.0  2472.0  2186.0  1617.5  1207.5
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 11219   431.0   834.5   834.5  2607.5  3096.0  2671.0  3299.5  1807.0   898.5
# 11220   484.0   834.5   834.5  2607.5  3096.0  3051.0  3299.5  1807.0   898.5
# 11223   725.5   999.0   999.0  2612.0  3111.5  3152.0  3446.5  1925.0  1072.5
# 11225   741.5   999.0   999.0  2612.0  3111.5  3572.0  3446.5  1925.0  1072.5
# 11228   835.0  1014.5  1014.5  2755.0  3407.5  3341.0  3487.0  2106.5  1182.5
#
#            ndwi      ndvi      ndbi
# 0     -0.226649  0.105779 -0.011038
# 2     -0.462794  0.329379 -0.182898
# 3     -0.483479  0.321123 -0.173959
# 4     -0.478112  0.334568 -0.143840
# 6     -0.525690  0.392872 -0.208950
# ...         ...       ...       ...
# 11219 -0.722115  0.523891 -0.192943
# 11220 -0.726167  0.570454 -0.256072
# 11223 -0.625790  0.518670 -0.241678
# 11225 -0.656196  0.562897 -0.299618
# 11228 -0.600096  0.534152 -0.226618
#
# [8354 rows x 18 columns]

# %%
#Building Neural Network 

#Check the scales of the features

#uhi_data_std = uhi_data
model1_data = uhi_data[['B01','B02', 'B03', 'B04', 'B05' , 'B08', 'B11','ndwi' , 'ndvi', 'ndbi' , 'UHI Index']]

#standardize the data in each column.
md1_data_std = model1_data.apply(lambda x: (x - x.mean()) / x.std(), axis=0) 
md1_data_std =md1_data_std.apply(lambda x: pd.to_numeric(x, errors = 'coerce'), axis=0) 


# Convert object columns to numeric
#for col in ['B02', 'B03', 'B05', 'B11']:
  #  model1_data[col] = pd.to_numeric(model1_data[col], errors='coerce')
for col in ['B02', 'B03', 'B05', 'B11']:
    na_count = md1_data_std[col].isna().sum()
    print(f"Number of NaN values in {col} after conversion: {na_count}")
    
print(md1_data_std.dtypes)
# Out:
# Number of NaN values in B02 after conversion: 0
# Number of NaN values in B03 after conversion: 0
# Number of NaN values in B05 after conversion: 0
# Number of NaN values in B11 after conversion: 0
# B01          float64
# B02          float64
# B03          float64
# B04          float64
# B05          float64
# B08          float64
# B11          float64
# ndwi         float64
# ndvi         float64
# ndbi         float64
# UHI Index    float64
# dtype: object

# %%
#Divide data into training and testing
#md1_data_std = pd.to_numeric(md1_data_std)
X = md1_data_std.drop(columns=['UHI Index']).values
y = md1_data_std['UHI Index'].values


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=123)
print(X_train.shape) 
print(y_test.shape)
# Out:
# (6683, 10)
# (1671,)

# %%
#Build neural network
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout


#Model 

model1 = Sequential([
    Dense(512 , input_shape=(10,), activation='relu'),
    Dense(128, activation = 'relu'),
    #Dense(30, activation = 'relu'),
    Dense(64 , activation = 'relu'),
    Dense(32, activation = 'relu'),
    Dense(16, activation = 'relu' ),
    Dense(1, activation = 'linear' ) #Output continous variable UHI index 
])


model1.compile(optimizer= 'RMSprop' , loss = "MSE" )

model1.fit(X_train, y_train, epochs=25)
# Out:
# Epoch 1/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step - loss: 0.9315
# Epoch 2/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 0.8752
# Epoch 3/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8549
# Epoch 4/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8726
# Epoch 5/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 0.8686
# Epoch 6/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 0.8378
# Epoch 7/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8439
# Epoch 8/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.8562
# Epoch 9/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8521
# Epoch 10/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8335
# Epoch 11/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8150
# Epoch 12/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8409
# Epoch 13/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 0.8116
# Epoch 14/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8143
# Epoch 15/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.7814
# Epoch 16/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.8219
# Epoch 17/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8168
# Epoch 18/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 0.8000
# Epoch 19/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.7917
# Epoch 20/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 0.8248
# Epoch 21/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 0.7844
# Epoch 22/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 0.7773
# Epoch 23/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7912
# Epoch 24/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7963
# Epoch 25/25
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 0.7886

# %%
model1.evaluate(X_test,  y_test, verbose=2)
# Out:
# 53/53 - 0s - 2ms/step - loss: 0.8636
# 0.8635626435279846

# %%
y_lazy_pred = np.mean(y_test)*np.ones(len(y_test))

#print(mean_squared_error(y_test , y_lazy_pred))


print(r2_score(y_test, model1.predict(X_test)))
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 0.13218250562912415

# %%
md2_data_std = md1_data_std[['B01', 'B05' , 'B08', 'B11','ndwi' , 'ndvi', 'ndbi' , 'UHI Index']]

X2 = md2_data_std.drop(columns=['UHI Index']).values
y2 = md2_data_std['UHI Index'].values


X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2,random_state=123)
print(X_train.shape) 
print(y_test.shape)
# Out:
# (6683, 10)
# (1671,)

# %%
#model using only the features used in the sample notebook 

model2 = Sequential([
    #Dense(512 , input_shape=(7,), activation='relu'),
    #Dense(128, activation = 'relu'),
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2), 
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2),
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2),
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2),
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2),
    Dense(30, activation = 'linear',
        kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation = 'relu'),
    Dropout(0.2),
    Dense(30, activation = 'linear'),
    Dense(30, activation = 'relu'),
    #Dense(64 , activation = 'relu'),
    #Dense(32, activation = 'relu'),
    #Dense(16, activation = 'relu' ),
    Dense(1, activation = 'linear' ) #Output continous variable UHI index 
])


model2.compile(optimizer= 'adam' , loss = "MSE" )

model2.fit(X2_train, y2_train, epochs=50 ,batch_size=10, validation_split=0.2 ) 

#model_lassoreg.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.0115 - val_loss: 1.2165
# Epoch 2/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1548 - val_loss: 1.0057
# Epoch 3/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9890 - val_loss: 0.9892
# Epoch 4/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9799 - val_loss: 1.0168
# Epoch 5/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9495 - val_loss: 0.9309
# Epoch 6/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9369 - val_loss: 0.9377
# Epoch 7/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9154 - val_loss: 0.9227
# Epoch 8/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9289 - val_loss: 0.9231
# Epoch 9/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9627 - val_loss: 0.9195
# Epoch 10/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9145 - val_loss: 0.9239
# Epoch 11/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9360 - val_loss: 0.9168
# Epoch 12/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9099 - val_loss: 0.9364
# Epoch 13/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9197 - val_loss: 0.9220
# Epoch 14/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9257 - val_loss: 0.9085
# Epoch 15/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9449 - val_loss: 0.9164
# Epoch 16/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9178 - val_loss: 0.9146
# Epoch 17/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8936 - val_loss: 0.9232
# Epoch 18/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8937 - val_loss: 0.9035
# Epoch 19/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9242 - val_loss: 0.9158
# Epoch 20/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9114 - val_loss: 0.9248
# Epoch 21/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9213 - val_loss: 0.9055
# Epoch 22/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9057 - val_loss: 0.9220
# Epoch 23/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9425 - val_loss: 0.9165
# Epoch 24/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8970 - val_loss: 0.9020
# Epoch 25/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9281 - val_loss: 0.9143
# Epoch 26/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9216 - val_loss: 0.9138
# Epoch 27/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8904 - val_loss: 0.9050
# Epoch 28/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8831 - val_loss: 0.9038
# Epoch 29/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8953 - val_loss: 0.9008
# Epoch 30/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9321 - val_loss: 0.9047
# Epoch 31/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9095 - val_loss: 0.9102
# Epoch 32/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9268 - val_loss: 0.8995
# Epoch 33/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9075 - val_loss: 0.9076
# Epoch 34/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9467 - val_loss: 0.9028
# Epoch 35/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8965 - val_loss: 0.9308
# Epoch 36/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9005 - val_loss: 0.8967
# Epoch 37/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9241 - val_loss: 0.9009
# Epoch 38/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8716 - val_loss: 0.8932
# Epoch 39/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9059 - val_loss: 0.9204
# Epoch 40/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8986 - val_loss: 0.9092
# Epoch 41/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8898 - val_loss: 0.8953
# Epoch 42/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9088 - val_loss: 0.9048
# Epoch 43/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8813 - val_loss: 0.8986
# Epoch 44/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9190 - val_loss: 0.9101
# Epoch 45/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9150 - val_loss: 0.9011
# Epoch 46/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9214 - val_loss: 0.8955
# Epoch 47/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8990 - val_loss: 0.8972
# Epoch 48/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8958 - val_loss: 0.8982
# Epoch 49/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8668 - val_loss: 0.9478
# Epoch 50/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9228 - val_loss: 0.8914

# %%
print(r2_score(y_test, model2.predict(X2_test)))
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step
# 0.11947834753868347

# %%
#Model with a regularizer to increas epocs and avoid overfitting

from tensorflow.keras import regularizers



model_lassoreg = Sequential([
    Dense(512 , input_shape=(10,), activation='relu'),
    Dropout(0.2),
    Dense(128, activation = 'linear' ,
        kernel_regularizer=regularizers.l2(0.01)),
    #Dense(30, activation = 'relu'),
    Dense(64 , activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.1)),
    Dense(32, activation = 'linear',
         kernel_regularizer=regularizers.l2(0.01)),
    Dense(16, activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.1)),
    Dense(1, activation = 'linear' ) #Output continous variable UHI index 
])


model_lassoreg.compile(optimizer= 'adam' , loss = "MSE" )

model_lassoreg.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 55.2669 - val_loss: 4.3807
# Epoch 2/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0770 - val_loss: 1.1767
# Epoch 3/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1342 - val_loss: 1.1101
# Epoch 4/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0740 - val_loss: 1.1024
# Epoch 5/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1046 - val_loss: 1.1014
# Epoch 6/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0829 - val_loss: 1.0996
# Epoch 7/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0937 - val_loss: 1.1005
# Epoch 8/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0682 - val_loss: 1.0999
# Epoch 9/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0968 - val_loss: 1.0991
# Epoch 10/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1185 - val_loss: 1.1013
# Epoch 11/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1217 - val_loss: 1.0993
# Epoch 12/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1251 - val_loss: 1.1006
# Epoch 13/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1132 - val_loss: 1.1003
# Epoch 14/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0895 - val_loss: 1.0995
# Epoch 15/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0974 - val_loss: 1.1004
# Epoch 16/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0847 - val_loss: 1.0998
# Epoch 17/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0777 - val_loss: 1.1009
# Epoch 18/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0787 - val_loss: 1.1000
# Epoch 19/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1035 - val_loss: 1.0992
# Epoch 20/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0836 - val_loss: 1.1007
# Epoch 21/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0754 - val_loss: 1.0997
# Epoch 22/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0833 - val_loss: 1.0989
# Epoch 23/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0676 - val_loss: 1.0994
# Epoch 24/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0875 - val_loss: 1.0997
# Epoch 25/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1052 - val_loss: 1.1002
# Epoch 26/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0856 - val_loss: 1.1009
# Epoch 27/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1038 - val_loss: 1.0984
# Epoch 28/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1029 - val_loss: 1.0996
# Epoch 29/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1026 - val_loss: 1.0992
# Epoch 30/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0940 - val_loss: 1.1007
# Epoch 31/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1059 - val_loss: 1.0999
# Epoch 32/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0917 - val_loss: 1.0995
# Epoch 33/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1116 - val_loss: 1.0992
# Epoch 34/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0972 - val_loss: 1.0998
# Epoch 35/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0608 - val_loss: 1.1007
# Epoch 36/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1053 - val_loss: 1.0992
# Epoch 37/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0749 - val_loss: 1.0994
# Epoch 38/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1164 - val_loss: 1.0995
# Epoch 39/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1254 - val_loss: 1.0996
# Epoch 40/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0856 - val_loss: 1.1002
# Epoch 41/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0902 - val_loss: 1.0990
# Epoch 42/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0914 - val_loss: 1.0990
# Epoch 43/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0671 - val_loss: 1.0995
# Epoch 44/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0682 - val_loss: 1.0983
# Epoch 45/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0915 - val_loss: 1.0995
# Epoch 46/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1230 - val_loss: 1.0992
# Epoch 47/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0965 - val_loss: 1.0996
# Epoch 48/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0770 - val_loss: 1.0997
# Epoch 49/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0925 - val_loss: 1.0998
# Epoch 50/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1310 - val_loss: 1.1010
# Epoch 51/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0844 - val_loss: 1.0995
# Epoch 52/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0969 - val_loss: 1.0994
# Epoch 53/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0846 - val_loss: 1.1003
# Epoch 54/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0905 - val_loss: 1.0984
# Epoch 55/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0961 - val_loss: 1.0996
# Epoch 56/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0849 - val_loss: 1.0994
# Epoch 57/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1058 - val_loss: 1.0994
# Epoch 58/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1202 - val_loss: 1.0997
# Epoch 59/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1141 - val_loss: 1.0996
# Epoch 60/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1066 - val_loss: 1.0994
# Epoch 61/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0633 - val_loss: 1.0994
# Epoch 62/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0865 - val_loss: 1.0992
# Epoch 63/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0883 - val_loss: 1.1002
# Epoch 64/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0911 - val_loss: 1.0995
# Epoch 65/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0570 - val_loss: 1.1005
# Epoch 66/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0837 - val_loss: 1.0987
# Epoch 67/100
# 138/168 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0607
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 25
#       7 model_lassoreg = Sequential([
#       8     Dense(512 , input_shape=(10,), activation='relu'),
#       9     Dropout(0.2),
#    (...)
#      19     Dense(1, activation = 'linear' ) #Output continous variable UHI index
#      20 ])
#      23 model_lassoreg.compile(optimizer= 'adam' , loss = "MSE" )
# ---> 25 model_lassoreg.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:249, in AtomicFunction.call_flat(self, *args)
#     242 with InterpolateRuntimeError(self):
#     243   with ops.control_dependencies(self._call_options.control_captures):
#     244     # The caller must use record_operation to record this operation in the
#     245     # eager case, so we enforce the same requirement for the non-eager
#     246     # case by explicitly pausing recording. We don't have a gradient
#     247     # registered for PartitionedCall, so recording this operation confuses
#     248     # forwardprop code (GradientTape manages to ignore it).
# --> 249     with record.stop_recording():
#     250       if self._bound_context.executing_eagerly():
#     251         outputs = self._bound_context.call_function(
#     252             self.name,
#     253             list(args),
#     254             len(self.function_type.flat_outputs),
#     255         )
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/contextlib.py:281, in contextmanager.<locals>.helper(*args, **kwds)
#     279 @wraps(func)
#     280 def helper(*args, **kwds):
# --> 281     return _GeneratorContextManager(func, args, kwds)
#
# File ~/Downloads/ENTER/envs/UHI/lib/python3.10/contextlib.py:102, in _GeneratorContextManagerBase.__init__(self, func, args, kwds)
#      99 class _GeneratorContextManagerBase:
#     100     """Shared functionality for @contextmanager and @asynccontextmanager."""
# --> 102     def __init__(self, func, args, kwds):
#     103         self.gen = func(*args, **kwds)
#     104         self.func, self.args, self.kwds = func, args, kwds
#
# KeyboardInterrupt:

# %%
print(r2_score(y_test, model_lassoreg.predict(X_test)))
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 0.1269695466287537

# %%
#attempt at helping the network find nonlinear relations
import itertools

md3_data = md1_data_std.copy()
feature_list = md3_data.drop(columns=['UHI Index']).columns.tolist()

column_combinations = itertools.combinations(feature_list, 2)
print(columns_to_check)
for col1, col2 in column_combinations:
    new_col_name = f'{col1}_{col2}'  # Name for the new column
    md3_data[new_col_name ] = md3_data[col1] * md3_data[col2]  # Multiply the column



len(feature_list)
md3_data.columns.to_list()
#md3_data.shape
# Out:
# ['B01', 'B04', 'B06', 'B08', 'ndvi']
# ['B01',
#  'B02',
#  'B03',
#  'B04',
#  'B05',
#  'B08',
#  'B11',
#  'ndwi',
#  'ndvi',
#  'ndbi',
#  'UHI Index',
#  'B01_B02',
#  'B01_B03',
#  'B01_B04',
#  'B01_B05',
#  'B01_B08',
#  'B01_B11',
#  'B01_ndwi',
#  'B01_ndvi',
#  'B01_ndbi',
#  'B02_B03',
#  'B02_B04',
#  'B02_B05',
#  'B02_B08',
#  'B02_B11',
#  'B02_ndwi',
#  'B02_ndvi',
#  'B02_ndbi',
#  'B03_B04',
#  'B03_B05',
#  'B03_B08',
#  'B03_B11',
#  'B03_ndwi',
#  'B03_ndvi',
#  'B03_ndbi',
#  'B04_B05',
#  'B04_B08',
#  'B04_B11',
#  'B04_ndwi',
#  'B04_ndvi',
#  'B04_ndbi',
#  'B05_B08',
#  'B05_B11',
#  'B05_ndwi',
#  'B05_ndvi',
#  'B05_ndbi',
#  'B08_B11',
#  'B08_ndwi',
#  'B08_ndvi',
#  'B08_ndbi',
#  'B11_ndwi',
#  'B11_ndvi',
#  'B11_ndbi',
#  'ndwi_ndvi',
#  'ndwi_ndbi',
#  'ndvi_ndbi']

# %%
X3 = md3_data.drop(columns=['UHI Index']).values
y3 = md3_data['UHI Index'].values


X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.2,random_state=125)
print(X3_train.shape) 
print(y3_test.shape)
# Out:
# (6683, 55)
# (1671,)

# %%
from tensorflow.keras import regularizers


quartic_md_reg = Sequential([
    Dense(2048 , input_shape=(55,), activation='linear'),
    Dropout(0.2),
    Dense(1024 , activation='relu'),
    Dropout(0.2),
    Dense(128, activation = 'linear' ,
        kernel_regularizer=regularizers.l2(0.5)),
    Dense(64 , activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(32, activation = 'linear',
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(16, activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(1, activation = 'linear' ) #Output continous variable UHI index 
])

#this architecture achieves the same result as the original DNN. 
'''quartic_md_reg = Sequential([
    Dense(2048 , input_shape=(55,), activation='linear'),
    Dropout(0.2),
    Dense(1024 , activation='relu'),
    Dropout(0.2),
    Dense(128, activation = 'linear' ,
        kernel_regularizer=regularizers.l2(0.5)),
    Dense(64 , activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(32, activation = 'linear',
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(16, activation = 'relu' ,
         kernel_regularizer=regularizers.l2(0.5)),
    Dense(1, activation = 'linear' ) #Output continous variable UHI index 
])''' 

quartic_md_reg.compile(optimizer= 'adam' , loss = "MSE" )

quartic_md_reg.fit(X3_train, y3_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 47.9798 - val_loss: 1.2515
# Epoch 2/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0417 - val_loss: 1.0741
# Epoch 3/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9677 - val_loss: 1.0730
# Epoch 4/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 1.0026 - val_loss: 1.0732
# Epoch 5/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 1.0141 - val_loss: 1.0730
# Epoch 6/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0130 - val_loss: 1.0731
# Epoch 7/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0222 - val_loss: 1.0733
# Epoch 8/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9925 - val_loss: 1.0731
# Epoch 9/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.0222 - val_loss: 1.0735
# Epoch 10/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0239 - val_loss: 1.0730
# Epoch 11/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9936 - val_loss: 1.0730
# Epoch 12/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9995 - val_loss: 1.0732
# Epoch 13/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9659 - val_loss: 1.0731
# Epoch 14/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0027 - val_loss: 1.0730
# Epoch 15/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9696 - val_loss: 1.0737
# Epoch 16/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9671 - val_loss: 1.0735
# Epoch 17/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9900 - val_loss: 1.0731
# Epoch 18/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.0052 - val_loss: 1.0733
# Epoch 19/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.9782 - val_loss: 1.0730
# Epoch 20/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9958 - val_loss: 1.0731
# Epoch 21/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.9904 - val_loss: 1.0733
# Epoch 22/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9728 - val_loss: 1.0732
# Epoch 23/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 1.0239 - val_loss: 1.0731
# Epoch 24/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 1.0012 - val_loss: 1.0732
# Epoch 25/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 1.0038 - val_loss: 1.0731
# Epoch 26/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 1.0054 - val_loss: 1.0731
# Epoch 27/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9888 - val_loss: 1.0732
# Epoch 28/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0073 - val_loss: 1.0731
# Epoch 29/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9898 - val_loss: 1.0731
# Epoch 30/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0029 - val_loss: 1.0731
# Epoch 31/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.9928 - val_loss: 1.0731
# Epoch 32/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.9999 - val_loss: 1.0731
# Epoch 33/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9854 - val_loss: 1.0731
# Epoch 34/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9942 - val_loss: 1.0731
# Epoch 35/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9804 - val_loss: 1.0731
# Epoch 36/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0232 - val_loss: 1.0731
# Epoch 37/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0169 - val_loss: 1.0731
# Epoch 38/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9942 - val_loss: 1.0731
# Epoch 39/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9776 - val_loss: 1.0731
# Epoch 40/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9725 - val_loss: 1.0731
# Epoch 41/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0046 - val_loss: 1.0731
# Epoch 42/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0074 - val_loss: 1.0732
# Epoch 43/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.0139 - val_loss: 1.0731
# Epoch 44/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9928 - val_loss: 1.0731
# Epoch 45/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9967 - val_loss: 1.0731
# Epoch 46/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.9959 - val_loss: 1.0734
# Epoch 47/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.0118 - val_loss: 1.0731
# Epoch 48/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0092 - val_loss: 1.0731
# Epoch 49/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.9807 - val_loss: 1.0731
# Epoch 50/50
# 535/535 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.9765 - val_loss: 1.0731

# %%
print(r2_score(y3_test, quartic_md_reg.predict(X3_test)))
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# -0.0002088499122305798
